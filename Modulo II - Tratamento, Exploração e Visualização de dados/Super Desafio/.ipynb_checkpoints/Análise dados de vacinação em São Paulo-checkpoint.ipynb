# %% [markdown]
# # Leitura dos dados

# %% [markdown]
# ## Resumo
#
# Esta análise tem como propósito realizar uma exploração nos dados adquiridos pelo site: http://tabnet.datasus.gov.br/ <br>
# Realizar o levantamento de hipóteses e comparação com outros dados adquiridos <br>
# O foco da análise será comparar o nível de analfabetismo e a quantia de vacinas aplicadas

# %% [markdown]
# ### Leitura dados de imunos aplicados

# %%
import pandas as pd

# %%
imunos = pd.read_csv('Dados/imunos.csv', encoding="ISO-8859-1", skiprows=3, sep=";", 
                    skipfooter=19, thousands=".", decimal=",")
imunos.head()
# Out:
# C:\Users\Kaiqu\anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação  072 BCG  099 Hepatite B  em crianças até 30 dias  \
# 0          11 Rondônia   800058                                   147439
# 1              12 Acre   435530                                    70747
# 2          13 Amazonas  2103147                                   407834
# 3           14 Roraima   278512                                    60492
# 4              15 Pará  4256283                                   590903
#
#    061 Rotavírus Humano  053 Meningococo C  073 Hepatite B  080 Penta  \
# 0                325125             241025          694872     190233
# 1                154135             115200          309240      86383
# 2                723347             578236         1421148     457595
# 3                107360              81724          200713      66426
# 4               1309459             916541         2740502     680391
#
#    012 Pneumocócica  074 Poliomielite  100 Poliomielite 4 anos  ...  \
# 0            239618            735112                        4  ...
# 1            107866            365231                       14  ...
# 2            551646           1631892                      196  ...
# 3             82928            223108                       51  ...
# 4            852483           3401216                       27  ...
#
#    097 Tetra Viral(SRC+VZ)  075 DTP  102 DTP REF (4 e 6 anos)  \
# 0                   140788   690768                      9576
# 1                    57472   290407                      8007
# 2                   342081  1436612                     32075
# 3                    54101   204177                      5248
# 4                   442269  3021306                     50829
#
#    103 Dupla Adulto (dt)  095 Tríplice Bacteriana(DTP)(1º ref)  018 Sarampo  \
# 0                 176383                                151634       288655
# 1                  67564                                 71422        98882
# 2                 455475                                368702       529118
# 3                  63330                                 58981        73860
# 4                 549869                                567459      1258013
#
#    009 Haemophilus influenzae b  \
# 0                         73011
# 1                         14394
# 2                        125201
# 3                         19972
# 4                        314660
#
#    094 Dupla adulto e tríplice acelular gestante  003 dTpa gestante     Total
# 0                                         102081              75538   7125165
# 1                                          33533              23914   3255004
# 2                                         258975             219924  16484500
# 3                                          33663              31173   2325302
# 4                                         293425             200201  29876882
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Leitura dados de pontuação de cobertura

# %%
cobertura = pd.read_csv('Dados/cobertura.csv', encoding="ISO-8859-1", skiprows=3, sep=";", 
                    skipfooter=19, thousands=".", decimal=",")
cobertura.head()
# Out:
# C:\Users\Kaiqu\anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação  072 BCG  099 Hepatite B  em crianças até 30 dias  \
# 0          11 Rondônia   105.11                                    77.44
# 1              12 Acre   105.54                                    60.09
# 2          13 Amazonas   107.99                                    74.39
# 3           14 Roraima   113.28                                    79.26
# 4              15 Pará   110.41                                    60.20
#
#    061 Rotavírus Humano  053 Meningococo C  073 Hepatite B  080 Penta  \
# 0                 61.92              60.80           91.29      87.89
# 1                 49.50              50.59           74.94      64.19
# 2                 49.73              55.81           72.97      73.35
# 3                 56.47              61.78           81.64      77.28
# 4                 46.96              45.99           71.09      60.53
#
#    012 Pneumocócica  074 Poliomielite  100 Poliomielite 4 anos  ...  \
# 0             89.21             96.58                     0.03  ...
# 1             64.09             88.50                     1.87  ...
# 2             71.17             83.79                     0.18  ...
# 3             78.81             90.74                     0.40  ...
# 4             60.49             88.23                     0.03  ...
#
#    098 Tríplice Viral  D2  097 Tetra Viral(SRC+VZ)  075 DTP  \
# 0                   83.98                    73.95    90.75
# 1                   54.17                    48.82    70.37
# 2                   69.89                    62.40    73.76
# 3                   75.17                    70.88    83.04
# 4                   51.81                    45.06    78.37
#
#    102 DTP REF (4 e 6 anos)  095 Tríplice Bacteriana(DTP)(1º ref)  \
# 0                      3.84                                 79.65
# 1                      4.94                                 60.67
# 2                      4.17                                 67.25
# 3                      5.31                                 77.28
# 4                      3.29                                 57.81
#
#    018 Sarampo  009 Haemophilus influenzae b  \
# 0        86.23                         25.12
# 1        69.04                         11.12
# 2        72.68                         19.29
# 3        89.77                         26.70
# 4        80.50                         22.59
#
#    094 Dupla adulto e tríplice acelular gestante  003 dTpa gestante  Total
# 0                                          53.88              39.87  83.29
# 1                                          28.64              20.42  67.15
# 2                                          47.39              40.24  72.01
# 3                                          44.48              41.19  78.16
# 4                                          29.93              20.42  68.07
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Leiura dados analfabetismo

# %%
analfabetismo = pd.read_csv('Dados/analfabetismo.csv', encoding="ISO-8859-1", skiprows=3, sep=";", 
                    skipfooter=2, thousands=".", decimal=",")
analfabetismo.head()
# Out:
# C:\Users\Kaiqu\anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação  1991  2000  2010  Total
# 0          11 Rondônia  19.6  12.3   8.8   12.7
# 1              12 Acre  34.3  23.6  16.6   22.7
# 2          13 Amazonas  23.9  15.0   9.9   14.7
# 3           14 Roraima  20.0  12.2  10.3   12.7
# 4              15 Pará  23.4  15.9  11.6   15.8

# %% [markdown]
# ## Tratamento Inicial: Remoção de números de UF

# %% [markdown]
# ### dataset: Imunos

# %%
imunos.set_index('Unidade da Federação', inplace = True)
imunos.index = imunos.index.str[3:]
imunos.head()
# Out:
#                       072 BCG  099 Hepatite B  em crianças até 30 dias  \
# Unidade da Federação
# Rondônia               800058                                   147439
# Acre                   435530                                    70747
# Amazonas              2103147                                   407834
# Roraima                278512                                    60492
# Pará                  4256283                                   590903
#
#                       061 Rotavírus Humano  053 Meningococo C  073 Hepatite B  \
# Unidade da Federação
# Rondônia                            325125             241025          694872
# Acre                                154135             115200          309240
# Amazonas                            723347             578236         1421148
# Roraima                             107360              81724          200713
# Pará                               1309459             916541         2740502
#
#                       080 Penta  012 Pneumocócica  074 Poliomielite  \
# Unidade da Federação
# Rondônia                 190233            239618            735112
# Acre                      86383            107866            365231
# Amazonas                 457595            551646           1631892
# Roraima                   66426             82928            223108
# Pará                     680391            852483           3401216
#
#                       100 Poliomielite 4 anos  006 Febre Amarela  ...  \
# Unidade da Federação                                              ...
# Rondônia                                    4             700726  ...
# Acre                                       14             317075  ...
# Amazonas                                  196            1563922  ...
# Roraima                                    51             206204  ...
# Pará                                       27            2893140  ...
#
#                       097 Tetra Viral(SRC+VZ)  075 DTP  \
# Unidade da Federação
# Rondônia                               140788   690768
# Acre                                    57472   290407
# Amazonas                               342081  1436612
# Roraima                                 54101   204177
# Pará                                   442269  3021306
#
#                       102 DTP REF (4 e 6 anos)  103 Dupla Adulto (dt)  \
# Unidade da Federação
# Rondônia                                  9576                 176383
# Acre                                      8007                  67564
# Amazonas                                 32075                 455475
# Roraima                                   5248                  63330
# Pará                                     50829                 549869
#
#                       095 Tríplice Bacteriana(DTP)(1º ref)  018 Sarampo  \
# Unidade da Federação
# Rondônia                                            151634       288655
# Acre                                                 71422        98882
# Amazonas                                            368702       529118
# Roraima                                              58981        73860
# Pará                                                567459      1258013
#
#                       009 Haemophilus influenzae b  \
# Unidade da Federação
# Rondônia                                     73011
# Acre                                         14394
# Amazonas                                    125201
# Roraima                                      19972
# Pará                                        314660
#
#                       094 Dupla adulto e tríplice acelular gestante  \
# Unidade da Federação
# Rondônia                                                     102081
# Acre                                                          33533
# Amazonas                                                     258975
# Roraima                                                       33663
# Pará                                                         293425
#
#                       003 dTpa gestante     Total
# Unidade da Federação
# Rondônia                          75538   7125165
# Acre                              23914   3255004
# Amazonas                         219924  16484500
# Roraima                           31173   2325302
# Pará                             200201  29876882
#
# [5 rows x 26 columns]

# %% [markdown]
# ### dataset: Cobertura

# %%
cobertura.set_index('Unidade da Federação', inplace = True)
cobertura.index = cobertura.index.str[3:]
cobertura.head()
# Out:
#                       072 BCG  099 Hepatite B  em crianças até 30 dias  \
# Unidade da Federação
# Rondônia               105.11                                    77.44
# Acre                   105.54                                    60.09
# Amazonas               107.99                                    74.39
# Roraima                113.28                                    79.26
# Pará                   110.41                                    60.20
#
#                       061 Rotavírus Humano  053 Meningococo C  073 Hepatite B  \
# Unidade da Federação
# Rondônia                             61.92              60.80           91.29
# Acre                                 49.50              50.59           74.94
# Amazonas                             49.73              55.81           72.97
# Roraima                              56.47              61.78           81.64
# Pará                                 46.96              45.99           71.09
#
#                       080 Penta  012 Pneumocócica  074 Poliomielite  \
# Unidade da Federação
# Rondônia                  87.89             89.21             96.58
# Acre                      64.19             64.09             88.50
# Amazonas                  73.35             71.17             83.79
# Roraima                   77.28             78.81             90.74
# Pará                      60.53             60.49             88.23
#
#                       100 Poliomielite 4 anos  006 Febre Amarela  ...  \
# Unidade da Federação                                              ...
# Rondônia                                 0.03              92.06  ...
# Acre                                     1.87              76.83  ...
# Amazonas                                 0.18              80.30  ...
# Roraima                                  0.40              83.87  ...
# Pará                                     0.03              75.05  ...
#
#                       098 Tríplice Viral  D2  097 Tetra Viral(SRC+VZ)  \
# Unidade da Federação
# Rondônia                               83.98                    73.95
# Acre                                   54.17                    48.82
# Amazonas                               69.89                    62.40
# Roraima                                75.17                    70.88
# Pará                                   51.81                    45.06
#
#                       075 DTP  102 DTP REF (4 e 6 anos)  \
# Unidade da Federação
# Rondônia                90.75                      3.84
# Acre                    70.37                      4.94
# Amazonas                73.76                      4.17
# Roraima                 83.04                      5.31
# Pará                    78.37                      3.29
#
#                       095 Tríplice Bacteriana(DTP)(1º ref)  018 Sarampo  \
# Unidade da Federação
# Rondônia                                             79.65        86.23
# Acre                                                 60.67        69.04
# Amazonas                                             67.25        72.68
# Roraima                                              77.28        89.77
# Pará                                                 57.81        80.50
#
#                       009 Haemophilus influenzae b  \
# Unidade da Federação
# Rondônia                                     25.12
# Acre                                         11.12
# Amazonas                                     19.29
# Roraima                                      26.70
# Pará                                         22.59
#
#                       094 Dupla adulto e tríplice acelular gestante  \
# Unidade da Federação
# Rondônia                                                      53.88
# Acre                                                          28.64
# Amazonas                                                      47.39
# Roraima                                                       44.48
# Pará                                                          29.93
#
#                       003 dTpa gestante  Total
# Unidade da Federação
# Rondônia                          39.87  83.29
# Acre                              20.42  67.15
# Amazonas                          40.24  72.01
# Roraima                           41.19  78.16
# Pará                              20.42  68.07
#
# [5 rows x 25 columns]

# %% [markdown]
# ### dataset: analfabetismo

# %%
analfabetismo.set_index('Unidade da Federação', inplace = True)
analfabetismo.index = analfabetismo.index.str[3:]
analfabetismo.head()
# Out:
#                       1991  2000  2010  Total
# Unidade da Federação
# Rondônia              19.6  12.3   8.8   12.7
# Acre                  34.3  23.6  16.6   22.7
# Amazonas              23.9  15.0   9.9   14.7
# Roraima               20.0  12.2  10.3   12.7
# Pará                  23.4  15.9  11.6   15.8

# %% [markdown]
# ### Seleção dos estados: São Paulo e Piauí

# %%
renome = {'Total':'total imunos'}
imunos.rename(columns = renome, inplace = True)
imunos_loc = imunos.loc[['São Paulo', 'Piauí']]['total imunos']

# %%
renome = {'Total':'total analfabetismo'}
analfabetismo.rename(columns = renome, inplace = True)
analfabetismo_loc = analfabetismo.loc[['São Paulo', 'Piauí']]['total analfabetismo']

# %%
renome = {'Total':'total cobertura'}
cobertura.rename(columns = renome, inplace = True)
cobertura_loc = cobertura.loc[['São Paulo', 'Piauí']]['total cobertura']

# %%
selecao = pd.DataFrame([imunos_loc, analfabetismo_loc, cobertura_loc])

# %%
selecao
# Out:
# Unidade da Federação     São Paulo        Piauí
# total imunos          1.342779e+08  11098552.00
# total analfabetismo   6.300000e+00        29.40
# total cobertura       7.461000e+01        70.29
